# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarpal1107/pythonbasics/blob/main/Exploratorydataanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Exploratory data analysis

# %%
1. Dataset Overview :-
The dataset contains 72,946 daily records from 56 cryptocurrencies. Each entry consists of
OHLC prices, trading volume, market capitalization, symbols, and dates. This wide dataset
provides strong coverage for volatility modelling.
2. Data Quality & Missing Values :-
No missing values were found in any of the nine columns. Numerical fields are consistent,
and the date column is properly parsed as datetime. This indicates a clean dataset ready for
modelling.
3. Descriptive Statistics :-
Price features exhibit high variance due to the presence of both small-cap and large-cap
crypto assets. Volume and market cap also show heavy skewness, reflecting massive
differences between coins such as Bitcoin and lesser-known tokens. Log-scaling or
normalization is recommended.

4. Cryptocurrency Coverage :-
The dataset includes 56 cryptocurrencies such as Bitcoin, Ethereum, BNB, Dogecoin, Solana,
and stablecoins like USDT and USDC. This diversity enables a broad volatility analysis across
market segments.
5. Initial Insights :-
• High variance in numerical values indicates need for scaling.
 • No missing data → minimal cleaning required.
 • Wide distribution of market caps helps build generalized volatility features.
 • Dataset is suitable for technical indicators and time-series features. 6. Conclusion of EDA :-
The dataset is clean, well-structured, and rich in information. It enables advanced feature
engineering such as rolling volatility, percentage returns, liquidity ratios, and technical
indicators. This forms a strong foundation for accurate cryptocurrency volatility prediction.
Plot Insights :-
A) Closing Price Trend (Sample Cryptocurrencies) :-
The line chart illustrates the closing price trends of five major cryptocurrencies—
Bitcoin, Litecoin, XRP, Dogecoin, and Monero—over a multi-year period from
2013 to 2023.
Key Observations :-
1. Bitcoin Dominates Price Movement
• Bitcoin shows the highest price levels, reaching peaks above $60,000
during the 2021 bull run.
• Its price trajectory is marked by multiple strong surges, followed by
significant corrections.
• The magnitude of Bitcoin’s movement visually overshadows the other
coins due to scale.
2. Altcoins Exhibit Lower but Distinct Trends
• Litecoin shows moderate volatility with noticeable peaks during crypto
market rallies.
• Monero also shows a steady upward trend over time but remains far below
Bitcoin’s scale.
• XRP has several strong spikes, especially during 2017 and 2021, reflecting
periods of increased speculation and news-driven momentum.
• Dogecoin remains mostly flat until late 2020–2021, when it experienced a
major surge fueled by social-media-driven hype. 3. Market-Wide Bull Runs are Clearly Visible
• Two major global crypto bull markets stand out across all coins:
• 2017–2018: First major surge affecting Bitcoin and most altcoins.
• 2020–2021: Largest market-wide rally, dramatically lifting prices across
all major cryptocurrencies.
4. Relative Comparison
• Bitcoin is the clear outlier with extremely high price peaks.
• Other coins appear comparatively flat on the graph due to Bitcoin’s scale,
although they exhibit their own volatility patterns when viewed individually.
Conclusion :-
The graph highlights the strong cyclical nature of cryptocurrency markets, with
synchronized bull runs across multiple assets. Bitcoin leads market movement with
extreme volatility, while altcoins follow similar trends on a smaller scale. The
visual data demonstrates how crypto prices fluctuate sharply over time, reinforcing
the importance of volatility prediction for risk management and informed decision-
making.
B) 14-Day Rolling Volatility (Aave) :-
• The graph shows the 14-day rolling volatility of the Aave cryptocurrency
from late 2020 to late 2022.
• There is a very high initial volatility spike, likely caused by early price
instability or limited trading data when Aave first entered the market.
• After the initial spike, volatility settles into a stable range between 0.05 and
0.15, indicating moderate and consistent price fluctuations.
• Short-term volatility increases are visible around mid-2021 and early 2022,
aligning with broader crypto market turbulence during those periods.
• Overall, Aave shows relatively low rolling volatility throughout most of the
timeline, suggesting a more stable price movement compared to the early
days. C) Volume vs Market Cap :-
• The scatter plot shows the relationship between trading volume and market
capitalization across all cryptocurrencies.
• Most points are clustered near the lower end of market cap, indicating that
many coins have relatively small valuation and moderate trading activity.
• A few coins with extremely high market caps (such as Bitcoin and Ethereum)
show higher but more stable trading volumes, visible as scattered points
toward the right.
• There are several extreme volume spikes, suggesting periods of intense
trading activity, possibly caused by market events or speculative movements.
• Overall, the plot shows a weak positive relationship: higher market cap coins
tend to have higher volume, but the distribution is noisy due to large
variability across cryptocurrencies.
D) Distribution of Daily Log Returns :-
• The histogram shows the distribution of daily log returns across all
cryptocurrencies.
• Most values are tightly concentrated around 0, indicating that small daily
price changes are the most common.
• The distribution exhibits heavy tails, with extreme spikes at both positive and
negative ends. This reflects the high volatility and occasional large price
swings typical in cryptocurrency markets.
• The shape is leptokurtic (very tall peak and fat tails), which is a common
characteristic of financial return data.
• These extreme outliers highlight the need for robust volatility modeling, as
crypto returns do not follow a simple normal distribution. E) Correlation Heatmap :-
• The heatmap shows extremely high positive correlations (≈1.0) among the
OHLC price features—open, high, low, and close.
This indicates that these price variables move almost identically, which is
expected in financial time-series data.
• Market cap shows a moderate positive correlation (~0.67) with price
features, meaning higher-valued cryptocurrencies tend to have higher prices
overall.
• Volume shows weak correlation (~0.26–0.27) with prices, suggesting that
trading activity does not directly depend on the price level.
• Volume’s correlation with market cap (0.46) is stronger but still moderate,
reflecting that large-cap coins generally have higher liquidity, though not
always proportionally.
• Overall, the heatmap highlights multicollinearity among the OHLC variables
— important to consider when selecting features for modeling.
